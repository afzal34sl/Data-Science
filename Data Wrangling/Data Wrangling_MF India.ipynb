# %%
# importing the data_patterns module
import data_patterns

# importing the pandas and numpy module
import pandas as pd
import numpy as np
from io import StringIO
import re

# %%
# # reading the given csv file
# # and creating dataframe
df_list = [] #as you want these as your headers 
check_scheme_name = 0
col_name=''
i=0
with open("Navaii MF.txt") as f:
    for line in f:
        # remove whitespace at the start and the newline at the end
        i=i+1
        if line == 3: continue
        line = line.strip()
        find_semi_colon = line.find(';')
        if line != '':
            if check_scheme_name == 0: 
                if find_semi_colon != -1:
                    columns = re.split(';', line)
                    if i==1: columns.insert(0, 'Company Name')
                    else: columns.insert(0, col_name)
                    df_list.append(columns)
                else:
                   check_scheme_name = 1
                   col_name = line

            elif check_scheme_name == 1:
                # split each column on whitespace
                columns = re.split(';', line)
                columns.insert(0, col_name)
                df_list.append(columns)
        else:
            check_scheme_name = 0

# %%
df_list
# Out:
# [['Company Name',
#   'Scheme Code',
#   'ISIN Div Payout/ ISIN Growth',
#   'ISIN Div Reinvestment',
#   'Scheme Name',
#   'Net Asset Value',
#   'Date'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119551',
#   'INF209KA12Z1',
#   'INF209KA13Z9',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - IDCW',
#   '142.5092',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119552',
#   'INF209K01YM2',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - MONTHLY IDCW',
#   '114.9651',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119553',
#   'INF209K01YO8',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - Direct - Quarterly IDCW',
#   '112.3226',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '108272',
#   'INF209K01LX6',
#   'INF209KA11Z3',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - IDCW',
#   '162.3519',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '110282',
#   'INF209K01LU2',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - MONTHLY IDCW',
#   '112.3741',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '108274',
#   'INF209K01LN7',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - REGULAR - Quarterly IDCW',
#   '109.9024',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '110490',
#   'INF209K01LR8',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - retail - monthly IDCW',
#   '112.231',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '106157',
#   'INF209K01LS6',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund  - retail - quarterly IDCW',
#   '112.6977',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '108273',
#   'INF209K01LV0',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund - Regular Plan-Growth',
#   '288.5234',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103176',
#   'INF209K01LT4',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund - Retail Plan-Growth',
#   '433.1101',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119550',
#   'INF209K01YN0',
#   '-',
#   'Aditya Birla Sun Life Banking & PSU Debt Fund- Direct Plan-Growth',
#   '295.4283',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '128952',
#   'INF846K01NF8',
#   '-',
#   'Axis Banking & PSU Debt Fund - Direct Plan - Bonus Option',
#   '1532.8272',
#   '14-Jun-2017'],
#  ['Axis Mutual Fund',
#   '120437',
#   '-',
#   'INF846K01CU0',
#   'Axis Banking & PSU Debt Fund - Direct Plan - Daily IDCW',
#   '1039.1310',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '120438',
#   'INF846K01CR6',
#   '-',
#   'Axis Banking & PSU Debt Fund - Direct Plan - Growth Option',
#   '2130.7335',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '120439',
#   'INF846K01CT2',
#   'INF846K01CS4',
#   'Axis Banking & PSU Debt Fund - Direct Plan - Monthly IDCW',
#   '1037.1090',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '120436',
#   'INF846K01CV8',
#   'INF846K01CW6',
#   'Axis Banking & PSU Debt Fund - Direct Plan - Weekly IDCW',
#   '1040.2057',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '128953',
#   'INF846K01NG6',
#   '-',
#   'Axis Banking & PSU Debt Fund - Regular Plan - Bonus Option',
#   '1289.4075',
#   '18-May-2015'],
#  ['Axis Mutual Fund',
#   '117447',
#   '-',
#   'INF846K01CC8',
#   'Axis Banking & PSU Debt Fund - Regular Plan - Daily IDCW',
#   '1039.1303',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '117446',
#   'INF846K01CB0',
#   '-',
#   'Axis Banking & PSU Debt Fund - Regular Plan - Growth option',
#   '2089.8694',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '117449',
#   'INF846K01CF1',
#   'INF846K01CG9',
#   'Axis Banking & PSU Debt Fund - Regular Plan - Monthly IDCW',
#   '1036.9274',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '117448',
#   'INF846K01CD6',
#   'INF846K01CE4',
#   'Axis Banking & PSU Debt Fund - Regular Plan - Weekly IDCW',
#   '1040.1701',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148629',
#   'INF955L01KF1',
#   'INF955L01KG9',
#   'Baroda Banking and PSU Bond Fund -Direct Plan-Monthly IDCW Option',
#   '10.2174',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148628',
#   'INF955L01KC8',
#   '-',
#   'Baroda Banking and PSU Bond Fund- Direct Plan -Growth Option',
#   '10.2174',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148630',
#   'INF955L01KD6',
#   'INF955L01KE4',
#   'Baroda Banking and PSU Bond Fund-Direct plan-Quarterly IDCW Option',
#   '10.1169',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148625',
#   'INF955L01JX6',
#   '-',
#   'Baroda Banking and PSU Bond Fund-Regular Plan -Growth Option',
#   '10.1922',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148626',
#   'INF955L01KA2',
#   'INF955L01KB0',
#   'Baroda Banking and PSU Bond Fund-Regular Plan -Monthly IDCW Option',
#   '10.1922',
#   '16-Jul-2021'],
#  ['Baroda Mutual Fund',
#   '148627',
#   'INF955L01JY4',
#   'INF955L01JZ1',
#   'Baroda Banking and PSU Bond Fund-Regular Plan-Quarterly IDCW Option',
#   '10.0917',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124175',
#   'INF740K01ZW2',
#   '-',
#   'DSP Banking & PSU Debt Fund - Direct Plan - Growth',
#   '19.4844',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124178',
#   'INF740K01A18',
#   'INF740K01A26',
#   'DSP Banking & PSU Debt Fund - Direct Plan - IDCW',
#   '10.3941',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124182',
#   '-',
#   'INF740KA1OF7',
#   'DSP Banking & PSU Debt Fund - Direct Plan - IDCW - Daily Reinvest',
#   '10.1600',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124176',
#   'INF740K01ZX0',
#   'INF740K01ZY8',
#   'DSP Banking & PSU Debt Fund - Direct Plan - IDCW - Monthly',
#   '10.2153',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124177',
#   'INF740K01ZZ5',
#   'INF740K01A00',
#   'DSP Banking & PSU Debt Fund - Direct Plan - IDCW - Quarterly ',
#   '10.1967',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124183',
#   'INF740KA1OG5',
#   'INF740KA1OH3',
#   'DSP Banking & PSU Debt Fund - Direct Plan - IDCW - Weekly',
#   '10.1695',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124172',
#   'INF740K01ZP6',
#   '-',
#   'DSP Banking & PSU Debt Fund - Regular Plan - Growth',
#   '19.0122',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124174',
#   'INF740K01ZU6',
#   'INF740K01ZV4',
#   'DSP Banking & PSU Debt Fund - Regular Plan - IDCW',
#   '10.3857',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124173',
#   '-',
#   'INF740KA1OI1',
#   'DSP Banking & PSU Debt Fund - Regular Plan - IDCW - Daily Reinvest',
#   '10.1600',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124180',
#   'INF740K01ZQ4',
#   'INF740K01ZR2',
#   'DSP Banking & PSU Debt Fund - Regular Plan - IDCW - Monthly',
#   '10.2130',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124181',
#   'INF740K01ZS0',
#   'INF740K01ZT8',
#   'DSP Banking & PSU Debt Fund - Regular Plan - IDCW - Quarterly ',
#   '10.1950',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '124179',
#   'INF740KA1OJ9',
#   'INF740KA1OK7',
#   'DSP Banking & PSU Debt Fund - Regular Plan - IDCW - Weekly',
#   '10.1695',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140286',
#   'INF843K01FC8',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Direct Plan - Growth Option',
#   '19.8299',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140288',
#   'INF843K01FD6',
#   'INF843K01FE4',
#   'Edelweiss Banking and PSU Debt Fund - Direct Plan - IDCW Option',
#   '18.996',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140291',
#   'INF843K01FG9',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Direct Plan Fortnightly - IDCW Option',
#   '15.3048',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140293',
#   'INF843K01FI5',
#   'INF843K01FH7',
#   'Edelweiss Banking and PSU Debt Fund - Direct Plan Monthly - IDCW Option',
#   '11.2834',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140290',
#   'INF843K01FF1',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Direct Plan weekly - IDCW Option',
#   '10.6188',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140283',
#   'INF843K01FK1',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Regular Plan - Growth Option',
#   '19.3784',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140284',
#   'INF843K01FL9',
#   'INF843K01FM7',
#   'Edelweiss Banking and PSU Debt Fund - Regular Plan - IDCW Option',
#   '18.546',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140294',
#   'INF843K01FO3',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Regular Plan Fortnightly - IDCW Option',
#   '14.9377',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140292',
#   'INF843K01FQ8',
#   'INF843K01FP0',
#   'Edelweiss Banking and PSU Debt Fund - Regular Plan Monthly - IDCW Option',
#   '11.2879',
#   '16-Jul-2021'],
#  ['Edelweiss Mutual Fund',
#   '140289',
#   'INF843K01FN5',
#   '-',
#   'Edelweiss Banking and PSU Debt Fund - Regular Plan Weekly - IDCW Option',
#   '10.4107',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '129008',
#   'INF090I01KR8',
#   '-',
#   'Franklin India Banking & PSU Debt Fund - Direct - Growth',
#   '18.3345',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '129006',
#   'INF090I01KO5',
#   '-',
#   'Franklin India Banking & PSU Debt Fund - Growth',
#   '17.7849',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '129009',
#   'INF090I01KS6',
#   'INF090I01KT4',
#   'Franklin India Banking and PSU Debt Fund - Direct - IDCW ',
#   '11.0042',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '129007',
#   'INF090I01KP2',
#   'INF090I01KQ0',
#   'Franklin India Banking and PSU Debt Fund - IDCW ',
#   '10.5797',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '128628',
#   'INF179KA1JC4',
#   '-',
#   'HDFC Banking and PSU Debt Fund - Growth Option',
#   '18.1658',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '128629',
#   'INF179KA1IZ7',
#   '-',
#   'HDFC Banking and PSU Debt Fund - Growth Option - Direct Plan',
#   '18.61',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '128627',
#   'INF179KA1JD2',
#   'INF179KA1JE0',
#   'HDFC Banking and PSU Debt Fund - IDCW Option',
#   '10.1599',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '128626',
#   'INF179KA1JA8',
#   'INF179KA1JB6',
#   'HDFC Banking and PSU Debt Fund - IDCW Option - Direct Plan',
#   '10.0501',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '112343',
#   'INF109K01WS5',
#   'INF109K01RV9',
#   'ICICI Prudential Banking and PSU Debt Fund -  Daily IDCW',
#   '10.0658',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '112344',
#   'INF109K01WR7',
#   'INF109K01RU1',
#   'ICICI Prudential Banking and PSU Debt Fund -  Weekly IDCW',
#   '10.2483',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '130897',
#   'INF109KA1B57',
#   '-',
#   'ICICI Prudential Banking and PSU Debt Fund - Bonus',
#   '15.8889',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '120257',
#   'INF109K01Z89',
#   'INF109K01Z97',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Daily IDCW',
#   '10.4328',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120256',
#   'INF109K010A6',
#   '-',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Growth',
#   '26.0492',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120258',
#   'INF109K011A4',
#   'INF109K012A2',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Quarterly IDCW',
#   '12.4773',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120255',
#   'INF109K013A0',
#   'INF109K014A8',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Weekly IDCW',
#   '10.3800',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '130950',
#   'INF109KA1B40',
#   '-',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan Bonus',
#   '13.8665',
#   '10-Apr-2018'],
#  ['ICICI Prudential Mutual Fund',
#   '131148',
#   'INF109KA1M96',
#   'INF109KA1M88',
#   'ICICI Prudential Banking and PSU Debt Fund - Direct Plan Half Yearly IDCW Option',
#   '13.2139',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '112342',
#   'INF109K01RT3',
#   '-',
#   'ICICI Prudential Banking and PSU Debt Fund - Growth',
#   '25.3700',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '116174',
#   'INF109K01YE1',
#   'INF109K01YD3',
#   'ICICI Prudential Banking and PSU Debt Fund - Quarterly IDCW',
#   '10.5855',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '131147',
#   'INF109KA1M70',
#   'INF109KA1M62',
#   'ICICI Prudential Banking and PSU Debt Fund Half Yearly IDCW Option',
#   '13.0141',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '113247',
#   'INF109K01WW7',
#   'INF109K01JM5',
#   'ICICI Prudential Banking and PSU Debt Fund Retail Daily Dividend',
#   '10.0122',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '113242',
#   'INF109K01II5',
#   '-',
#   'ICICI Prudential Banking and PSU Debt Fund Retail Growth',
#   '21.631',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '113243',
#   'INF109K01WV9',
#   'INF109K01IJ3',
#   'ICICI Prudential Banking and PSU Debt Fund Retail Weekly Dividend',
#   '10.3305',
#   '20-Aug-2015'],
#  ['IDFC Mutual Fund',
#   '121936',
#   'INF194K019M8',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Annual IDCW',
#   '12.0760',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '127471',
#   '-',
#   'INF194KA1JD3',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Daily IDCW',
#   '10.4768',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121934',
#   '-',
#   'INF194K010N5',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Fortnightly IDCW',
#   '10.5038',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121279',
#   'INF194K015G8',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Growth',
#   '19.8765',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121281',
#   'INF194K016G6',
#   'INF194K017G4',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct IDCW',
#   '10.4562',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121935',
#   '-',
#   'INF194K011N3',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Monthly IDCW',
#   '10.4808',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121938',
#   'INF194K018M0',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Direct Quarterly IDCW',
#   '10.6863',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121933',
#   'INF194K015M6',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Annual IDCW',
#   '11.1241',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '127470',
#   '-',
#   'INF194KA1JC5',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Daily IDCW',
#   '10.8788',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121931',
#   '-',
#   'INF194K016M4',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Fortnightly IDCW',
#   '10.6569',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121280',
#   'INF194K01SN6',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Growth',
#   '19.5471',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121282',
#   'INF194K01SO4',
#   'INF194K012D2',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular IDCW',
#   '10.5552',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121932',
#   '-',
#   'INF194K017M2',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Monthly IDCW',
#   '10.7245',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '121937',
#   'INF194K014M9',
#   '-',
#   'IDFC-IDFC Banking & PSU Debt Fund - Regular Quarterly IDCW',
#   '10.6034',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '118234',
#   '-',
#   'INF205K01JX8',
#   'Invesco India Banking & PSU Debt Fund - Daily IDCW (Reinvestment)',
#   '997.1298',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '120444',
#   'INF205K01KT4',
#   '-',
#   'Invesco India Banking & PSU Debt Fund - Direct Plan -  Growth Option',
#   '1929.0888',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '120443',
#   '-',
#   'INF205K01KS6',
#   'Invesco India Banking & PSU Debt Fund - Direct Plan - Daily IDCW (Reinvestment)',
#   '1014.3027',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '120445',
#   'INF205K01KU2',
#   'INF205K01KV0',
#   'Invesco India Banking & PSU Debt Fund - Direct Plan - Monthly IDCW (Payout / Reinvestment)',
#   '1011.2488',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '118232',
#   'INF205K01JV2',
#   '-',
#   'Invesco India Banking & PSU Debt Fund - Growth Option',
#   '1828.5074',
#   '16-Jul-2021'],
#  ['Invesco Mutual Fund',
#   '118233',
#   'INF205K01JW0',
#   'INF205K01JY6',
#   'Invesco India Banking & PSU Debt Fund - Monthly IDCW (Payout / Reinvestment)',
#   '1020.0927',
#   '16-Jul-2021'],
#  ['ITI Mutual Fund',
#   '148534',
#   'INF00XX01861',
#   '-',
#   'ITI Banking & PSU Debt Fund - Direct Plan - Growth Option',
#   '10.3639',
#   '16-Jul-2021'],
#  ['ITI Mutual Fund',
#   '148536',
#   'INF00XX01879',
#   'INF00XX01887',
#   'ITI Banking & PSU Debt Fund - Direct Plan - IDCW Option',
#   '10.3639',
#   '16-Jul-2021'],
#  ['ITI Mutual Fund',
#   '148535',
#   'INF00XX01838',
#   '-',
#   'ITI Banking & PSU Debt Fund - Regular Plan - Growth Option',
#   '10.3222',
#   '16-Jul-2021'],
#  ['ITI Mutual Fund',
#   '148533',
#   'INF00XX01846',
#   'INF00XX01853',
#   'ITI Banking & PSU Debt Fund - Regular Plan - IDCW Option',
#   '10.3222',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '123688',
#   'INF174K01FS4',
#   'INF174K01FR6',
#   'Kotak Banking and PSU Debt - Annual Dividend',
#   '16.1842',
#   '15-Sep-2017'],
#  ['Kotak Mahindra Mutual Fund',
#   '123858',
#   '-',
#   'INF174K01SD9',
#   'Kotak Banking and PSU Debt - Daily Dividend Reinvestment',
#   '10.188',
#   '15-Sep-2017'],
#  ['Kotak Mahindra Mutual Fund',
#   '123859',
#   'INF174K01SE7',
#   '-',
#   'Kotak Banking and PSU Debt - Direct Daily Dividend Reinvestment',
#   '10.2604',
#   '15-Sep-2017'],
#  ['Kotak Mahindra Mutual Fund',
#   '123690',
#   'INF174K01FO3',
#   '-',
#   'Kotak Banking and PSU Debt - Growth',
#   '51.193',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '123691',
#   'INF174K01FQ8',
#   'INF174K01FP0',
#   'Kotak Banking and PSU Debt - Monthly Payout of Income Distribution cum capital withdrawal option',
#   '10.4161',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '123689',
#   'INF174K01KI5',
#   'INF174K01KJ3',
#   'Kotak Banking and PSU Debt Direct - Annual Dividend',
#   '17.1427',
#   '15-Sep-2017'],
#  ['Kotak Mahindra Mutual Fund',
#   '123693',
#   'INF174K01KH7',
#   '-',
#   'Kotak Banking and PSU Debt Direct - Growth',
#   '52.4849',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '123692',
#   'INF174K01KK1',
#   '-',
#   'Kotak Banking and PSU Debt Direct - Monthly Payout of Income Distribution cum capital withdrawal option',
#   '10.3825',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '119794',
#   'INF917K01HI3',
#   '-',
#   'L&T Banking and PSU Debt Fund -  Direct Plan - Monthly IDCW',
#   '11.7614',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '118080',
#   'INF677K01AI8',
#   'INF677K01AJ6',
#   'L&T Banking and PSU Debt Fund -  Regular Plan - Monthly IDCW',
#   '11.3292',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '119796',
#   '-',
#   'INF917K01HL7',
#   'L&T Banking and PSU Debt Fund - Direct Plan - Daily IDCW ',
#   '11.1907',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '119795',
#   'INF917K01HH5',
#   '-',
#   'L&T Banking and PSU Debt Fund - Direct Plan - Growth',
#   '20.4779',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '119797',
#   '-',
#   'INF917K01HK9',
#   'L&T Banking and PSU Debt Fund - Direct Plan - Weekly IDCW',
#   '10.8383',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '118076',
#   '-',
#   'INF677K01AF4',
#   'L&T Banking and PSU Debt Fund - Regular Plan - Daily IDCW',
#   '11.116',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '118078',
#   'INF677K01AE7',
#   '-',
#   'L&T Banking and PSU Debt Fund - Regular Plan - Growth',
#   '19.7354',
#   '16-Jul-2021'],
#  ['L&T Mutual Fund',
#   '118077',
#   'INF917K01HM5',
#   'INF677K01AH0',
#   'L&T Banking and PSU Debt Fund - Regular Plan - Weekly IDCW',
#   '10.8298',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '120337',
#   'INF767K01GJ2',
#   'INF767K01GM6',
#   'LIC MF Banking & PSU Debt Fund-Direct Plan-Daily IDCW',
#   '11.8662',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '120338',
#   'INF767K01GI4',
#   '-',
#   'LIC MF Banking & PSU Debt Fund-Direct Plan-Growth',
#   '29.3268',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '120339',
#   'INF767K01GK0',
#   'INF767K01GN4',
#   'LIC MF Banking & PSU Debt Fund-Direct Plan-Monthly IDCW',
#   '11.0449',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '120336',
#   'INF767K01GL8',
#   'INF767K01GO2',
#   'LIC MF Banking & PSU Debt Fund-Direct Plan-Weekly IDCW',
#   '10.0115',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '105822',
#   'INF767K01519',
#   'INF767K01527',
#   'LIC MF Banking & PSU Debt Fund-Regular Plan-Daily IDCW',
#   '10.6923',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '105823',
#   'INF767K01535',
#   '-',
#   'LIC MF Banking & PSU Debt Fund-Regular Plan-Growth',
#   '27.7638',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '105856',
#   'INF767K01543',
#   'INF767K01550',
#   'LIC MF Banking & PSU Debt Fund-Regular Plan-Monthly IDCW',
#   '10.5496',
#   '16-Jul-2021'],
#  ['LIC Mutual Fund',
#   '105857',
#   'INF767K01568',
#   'INF767K01576',
#   'LIC MF Banking & PSU Debt Fund-Regular Plan-Weekly IDCW',
#   '10.0372',
#   '16-Jul-2021'],
#  ['Mirae Asset Mutual Fund',
#   '148419',
#   'INF769K01FY9',
#   '-',
#   'Mirae Asset Banking and PSU Debt Fund Direct Growth',
#   '10.4201',
#   '16-Jul-2021'],
#  ['Mirae Asset Mutual Fund',
#   '148417',
#   'INF769K01FX1',
#   'INF769K01FZ6',
#   'Mirae Asset Banking and PSU Debt Fund Direct IDCW',
#   '10.4200',
#   '16-Jul-2021'],
#  ['Mirae Asset Mutual Fund',
#   '148416',
#   'INF769K01FV5',
#   '-',
#   'Mirae Asset Banking and PSU Debt Fund Regular Growth Plan',
#   '10.3741',
#   '16-Jul-2021'],
#  ['Mirae Asset Mutual Fund',
#   '148418',
#   'INF769K01FU7',
#   'INF769K01FW3',
#   'Mirae Asset Banking and PSU Debt Fund Regular IDCW',
#   '10.3744',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134552',
#   'INF204KA1U61',
#   '-',
#   'Nippon India Banking  & PSU Debt Fund- Direct Plan-Growth Plan- Bonus Option',
#   '16.7256',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134547',
#   'INF204KA1U53',
#   '-',
#   'Nippon India Banking  & PSU Debt Fund- Direct Plan-Growth Plan- Growth Option',
#   '16.7254',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134546',
#   'INF204KA1T64',
#   '-',
#   'Nippon India Banking  & PSU Debt Fund- Growth Plan- Bonus Option',
#   '12.3452',
#   '02-Feb-2018'],
#  ['Nippon India Mutual Fund',
#   '134545',
#   'INF204KA1T56',
#   '-',
#   'Nippon India Banking  & PSU Debt Fund- Growth Plan- Growth Option',
#   '16.3910',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134555',
#   'INF204KA1U79',
#   'INF204KA1U87',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - Direct Plan - IDCW Option',
#   '16.7254',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134550',
#   'INF204KA1V37',
#   'INF204KA1V45',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - Direct Plan - MONTHLY IDCW Option',
#   '10.6538',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134556',
#   'INF204KA1U95',
#   'INF204KA1V03',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - Direct Plan - QUARTERLY IDCW Option',
#   '10.6015',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134554',
#   'INF204KA1V11',
#   'INF204KA1V29',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - Direct Plan - WEEKLY IDCW Option',
#   '10.3445',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134548',
#   'INF204KA1T72',
#   'INF204KA1T80',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - IDCW Option',
#   '16.3910',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134549',
#   'INF204KA1U38',
#   'INF204KA1U46',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - MONTHLY IDCW Option',
#   '10.5958',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134551',
#   'INF204KA1T98',
#   'INF204KA1U04',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - QUARTERLY IDCW Option',
#   '10.5752',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '134553',
#   'INF204KA1U12',
#   'INF204KA1U20',
#   'NIPPON INDIA BANKING & PSU DEBT FUND - WEEKLY IDCW Option',
#   '10.3450',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138573',
#   'INF223J01VH1',
#   '-',
#   'PGIM India Banking and PSU Debt fund - Bonus',
#   '13.3974',
#   '01-Aug-2016'],
#  ['PGIM India Mutual Fund',
#   '138580',
#   '-',
#   '-',
#   'PGIM India Banking and PSU Debt Fund - Direct Plan - Regular Dividend',
#   '10.273',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138565',
#   'INF223J01SU0',
#   '-',
#   'PGIM India Banking and PSU Debt fund - Monthly Dividend',
#   '10.7742',
#   '05-Mar-2021'],
#  ['PGIM India Mutual Fund',
#   '138576',
#   'INF223J01VF5',
#   '-',
#   'PGIM India Banking and PSU Debt fund - Quarterly Bonus',
#   '11.6111',
#   '01-Aug-2016'],
#  ['PGIM India Mutual Fund',
#   '138571',
#   'INF223J01VV2',
#   '-',
#   'PGIM India Banking and PSU Debt fund - Quarterly Dividend',
#   '10.8476',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138579',
#   '-',
#   '-',
#   'PGIM India Banking and PSU Debt Fund - Regular Dividend',
#   '10.2826',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138570',
#   'INF223J01VT6',
#   'INF223J01VU4',
#   'PGIM India Banking and PSU Debt fund - Weekly Dividend',
#   '10.2735',
#   '28-Jul-2019'],
#  ['PGIM India Mutual Fund',
#   '138566',
#   'INF223J01SW6',
#   '-',
#   'PGIM India Banking and PSU Debt fund -Growth',
#   '19.3313',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138575',
#   'INF223J01VG3',
#   '-',
#   'PGIM India Banking and PSU Debt fund- Direct Plan-  Quarterly Bonus',
#   '13.6246',
#   '01-Aug-2016'],
#  ['PGIM India Mutual Fund',
#   '138574',
#   'INF223J01VI9',
#   '-',
#   'PGIM India Banking and PSU Debt fund- Direct Plan-  Regular Bonus',
#   '15.2364',
#   '19-Jun-2018'],
#  ['PGIM India Mutual Fund',
#   '138568',
#   'INF223J01WD8',
#   '-',
#   'PGIM India Banking and PSU Debt fund- Direct Plan- Annual Dividend',
#   '11.0995',
#   '05-Mar-2021'],
#  ['PGIM India Mutual Fund',
#   '138563',
#   'INF223J01SX4',
#   'INF223J01SY2',
#   'PGIM India Banking and PSU Debt fund- Direct Plan- Monthly Dividend',
#   '10.9284',
#   '05-Mar-2021'],
#  ['PGIM India Mutual Fund',
#   '138567',
#   'INF223J01WB2',
#   '-',
#   'PGIM India Banking and PSU Debt fund- Direct Plan- Quarterly Dividend',
#   '10.8536',
#   '16-Jul-2021'],
#  ['PGIM India Mutual Fund',
#   '138569',
#   'INF223J01VZ3',
#   'INF223J01WA4',
#   'PGIM India Banking and PSU Debt fund- Direct Plan- Weekly Dividend',
#   '10.2259',
#   '28-Jul-2019'],
#  ['PGIM India Mutual Fund',
#   '138564',
#   'INF223J01SZ9',
#   '-',
#   'PGIM India Banking and PSU Debt fund- Direct Plan-Growth',
#   '20.1207',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125502',
#   '-',
#   'INF200K01V16',
#   'SBI Banking & PSU Fund - Direct Plan - Daily Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1144.3418',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125503',
#   'INF200K01V08',
#   '-',
#   'SBI BANKING & PSU FUND - Direct Plan - Growth',
#   '2597.9830',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125505',
#   'INF200K01V40',
#   'INF200K01V57',
#   'SBI Banking & PSU Fund - Direct Plan - Monthly Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1159.1857',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125504',
#   'INF200K01V32',
#   'INF200K01V24',
#   'SBI Banking & PSU Fund - Direct Plan - Weekly Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1141.7996',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125498',
#   'INF200K01U41',
#   '-',
#   'SBI BANKING & PSU FUND - Regular Paln - Growth',
#   '2489.7120',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125499',
#   '-',
#   'INF200K01U58',
#   'SBI Banking & PSU Fund - Regular Plan - Daily Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1135.8475',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125501',
#   'INF200K01U82',
#   'INF200K01U90',
#   'SBI Banking & PSU Fund - Regular Plan - Monthly Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1114.7361',
#   '16-Jul-2021'],
#  ['SBI Mutual Fund',
#   '125500',
#   'INF200K01U74',
#   'INF200K01U66',
#   'SBI Banking & PSU Fund - Regular Plan - Weekly Income Distribution cum Capital Withdrawal Option (IDCW)',
#   '1135.6372',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '134363',
#   'INF903J017I5',
#   '-',
#   'Sundaram Banking & PSU Debt Fund - Direct Growth',
#   '11.7065',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '134370',
#   'INF903J012J4',
#   'INF903J013J2',
#   'Sundaram Banking & PSU Debt Fund - Direct Monthly Dividend',
#   '11.4008',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '134369',
#   'INF903J019I1',
#   'INF903J014J0',
#   'Sundaram Banking & PSU Debt Fund - Direct Quarterly Dividend',
#   '10.6356',
#   '31-Mar-2016'],
#  ['Sundaram Mutual Fund',
#   '134355',
#   'INF903J016I7',
#   '-',
#   'Sundaram Banking & PSU Debt Fund - Regular Annual Bonus',
#   '11.6319',
#   '17-Feb-2017'],
#  ['Sundaram Mutual Fund',
#   '134356',
#   'INF903J016H9',
#   '-',
#   'Sundaram Banking & PSU Debt Fund - Regular Growth',
#   '11.6493',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '134359',
#   'INF903J018H5',
#   'INF903J012I6',
#   'Sundaram Banking & PSU Debt Fund - Regular Monthly Dividend',
#   '11.1411',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '134361',
#   'INF903J014I2',
#   '-',
#   'Sundaram Banking & PSU Debt Fund - Regular Quarterly Bonus',
#   '11.1681',
#   '16-Aug-2016'],
#  ['Sundaram Mutual Fund',
#   '134360',
#   'INF903J017H7',
#   'INF903J011I8',
#   'Sundaram Banking & PSU Debt Fund - Regular Weekly Dividend',
#   '10.1418',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '134362',
#   'INF903J019H3',
#   'INF903J013I4',
#   'Sundaram Banking & PSU Debt Fund Regular Quarterly Dividend',
#   '11.0236',
#   '17-Mar-2017'],
#  ['Sundaram Mutual Fund',
#   '119629',
#   'INF903J01RI4',
#   '-',
#   'Sundaram Banking and PSU Debt Fund Direct Plan - Bonus',
#   '17.2776',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '119627',
#   '-',
#   'INF903J01PC1',
#   'Sundaram Banking and PSU Debt Fund Direct Plan - Daily Reinvestment of Income Distribution cum Capital Withdrawal (IDCW)',
#   '10.2300',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '119625',
#   'INF903J01PA5',
#   '-',
#   'Sundaram Banking and PSU Debt Fund Direct Plan - Growth',
#   '34.5262',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '119626',
#   'INF903J01PB3',
#   'INF903J01PE7',
#   'Sundaram Banking and PSU Debt Fund Direct Plan - Monthly Income Distribution cum Capital Withdrawal (IDCW)',
#   '11.5403',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '118326',
#   'INF903J01LY4',
#   '-',
#   'Sundaram Banking and PSU Debt Fund Regular Plan - Bonus',
#   '17.2649',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100782',
#   '-',
#   'INF903J01IP8',
#   'Sundaram Banking and PSU Debt Fund Regular Plan - Daily Reinvestment of Income Distribution cum Capital Withdrawal (IDCW)',
#   '10.3550',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100784',
#   'INF903J01IN3',
#   '-',
#   'Sundaram Banking and PSU Debt Fund Regular Plan - Growth',
#   '34.2371',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100793',
#   'INF903J01IO1',
#   'INF903J01IR4',
#   'Sundaram Banking and PSU Debt Fund Regular Plan - Monthly Income Distribution cum Capital Withdrawal (IDCW)',
#   '11.5918',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100783',
#   '-',
#   'INF903J01IQ6',
#   'Sundaram Banking and PSU Debt Fund Regular Plan - Weekly Reinvestment of Income Distribution cum Capital Withdrawal (IDCW)',
#   '12.1029',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100781',
#   'INF903J01IK9',
#   '-',
#   'Sundaram Banking and PSU Debt Fund Retail Plan - Growth',
#   '30.8639',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '100780',
#   'INF903J01IL7',
#   'INF903J01IM5',
#   'Sundaram Banking and PSU Debt Fund Retail Plan - Monthly Income Distribution cum Capital Withdrawal (IDCW)',
#   '11.4965',
#   '16-Jul-2021'],
#  ['Sundaram Mutual Fund',
#   '134358',
#   '-',
#   'INF903J010I0',
#   'SundaramBanking&PSUDebtFund-RegularDailyDividendReinvestment',
#   '11.6582',
#   '17-Mar-2017'],
#  ['Tata Mutual Fund',
#   '147637',
#   'INF277K016X1',
#   '-',
#   'Tata Banking & PSU Debt Fund  Direct Plan - Payout of Income Distribution cum capital withdrawal option ',
#   '11.5184',
#   '16-Jul-2021'],
#  ['Tata Mutual Fund',
#   '147638',
#   '-',
#   'INF277K014X6',
#   'Tata Banking & PSU Debt Fund  Direct Plan - Reinvestment of Income Distribution cum capital withdrawal option ',
#   '11.5184',
#   '16-Jul-2021'],
#  ['Tata Mutual Fund',
#   '147634',
#   'INF277K013X8',
#   '-',
#   'Tata Banking & PSU Debt Fund Regular Plan - Payout of Income Distribution cum capital withdrawal option ',
#   '11.4143',
#   '16-Jul-2021'],
#  ['Tata Mutual Fund',
#   '147633',
#   '-',
#   'INF277K012X0',
#   'Tata Banking & PSU Debt Fund Regular Plan - Reinvestment of Income Distribution cum capital withdrawal option ',
#   '11.4143',
#   '16-Jul-2021'],
#  ['Tata Mutual Fund',
#   '147636',
#   'INF277K015X3',
#   '-',
#   'Tata Banking & PSU Debt Fund-Direct Plan-Growth',
#   '11.5184',
#   '16-Jul-2021'],
#  ['Tata Mutual Fund',
#   '147635',
#   'INF277K011X2',
#   '-',
#   'Tata Banking & PSU Debt Fund-Regular Plan-Growth',
#   '11.4143',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148656',
#   'INF0GCD01107',
#   '-',
#   'TRUSTMF BANKING & PSU DEBT FUND - DIRECT GROWTH',
#   '1023.5286',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148655',
#   'INF0GCD01016',
#   '-',
#   'TRUSTMF BANKING & PSU DEBT FUND - REGULAR GROWTH',
#   '1021.2011',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148672',
#   'INF0GCD01180',
#   'INF0GCD01172',
#   'TRUSTMF BANKING & PSU DEBT FUND DIRECT PLAN ANNUAL INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL OPTION',
#   '1023.5319',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148678',
#   '-',
#   'INF0GCD01115',
#   'TRUSTMF BANKING & PSU DEBT FUND DIRECT PLAN DAILY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1023.9449',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148681',
#   'INF0GCD01149',
#   'INF0GCD01131',
#   'TRUSTMF BANKING & PSU DEBT FUND DIRECT PLAN MONTHLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL OPTION',
#   '1015.1051',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148670',
#   'INF0GCD01164',
#   'INF0GCD01156',
#   'TRUSTMF BANKING & PSU DEBT FUND DIRECT PLAN QUARTERLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1023.5447',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148675',
#   '-',
#   'INF0GCD01123',
#   'TRUSTMF BANKING & PSU DEBT FUND DIRECT PLAN WEEKLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1014.406',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148669',
#   'INF0GCD01099',
#   'INF0GCD01081',
#   'TRUSTMF BANKING & PSU DEBT FUND REGULAR PLAN ANNUAL INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1021.205',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148667',
#   '-',
#   'INF0GCD01024',
#   'TRUSTMF BANKING & PSU DEBT FUND REGULAR PLAN DAILY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1021.2081',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148674',
#   'INF0GCD01057',
#   'INF0GCD01040',
#   'TRUSTMF BANKING & PSU DEBT FUND REGULAR PLAN MONTHLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1012.8977',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148668',
#   'INF0GCD01073',
#   'INF0GCD01065',
#   'TRUSTMF BANKING & PSU DEBT FUND REGULAR PLAN QUARTERLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1020.99',
#   '16-Jul-2021'],
#  ['Trust Mutual Fund',
#   '148679',
#   '-',
#   'INF0GCD01032',
#   'TRUSTMF BANKING & PSU DEBT FUND REGULAR PLAN WEEKLY INCOME DISTRIBUTION CUM CAPITAL WITHDRAWAL',
#   '1013.0563',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '140135',
#   'INF789FA1V03',
#   'INF789FA1V11',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Annual IDCW',
#   '11.1201',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '133972',
#   'INF789FA1V29',
#   'INF789FA1V37',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Flexi IDCW',
#   '14.1662',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '126940',
#   'INF789F015Z6',
#   '-',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Growth Option',
#   '16.4393',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '141375',
#   'INF789FA1U87',
#   'INF789FA1U95',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Half-Yearly IDCW',
#   '11.0327',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '134026',
#   'INF789FC1HE1',
#   'INF789FC1HF8',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Monthly IDCW',
#   '11.9589',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '126942',
#   'INF789F016Z4',
#   'INF789F017Z2',
#   'UTI Banking & PSU Debt Fund - Direct Plan - Quarterly IDCW',
#   '12.4298',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '140116',
#   'INF789FAIU46',
#   'INF789FA1U53',
#   'UTI Banking & PSU Debt Fund - Regular Plan - Annual IDCW',
#   '11.0484',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '133971',
#   'INF789FA1U61',
#   'INF789FA1U79',
#   'UTI Banking & PSU Debt Fund - Regular Plan - Flexi IDCW',
#   '10.9496',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '139407',
#   'INF789FA1U20',
#   'INF789FA1U38',
#   'UTI Banking & PSU Debt Fund - Regular Plan - Half-Yearly IDCW',
#   '11.0279',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '136110',
#   'INF789FC1HC5',
#   'INF789FC1HD3',
#   'UTI Banking & PSU Debt Fund - Regular Plan - Monthly IDCW',
#   '11.9043',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '126941',
#   'INF789F012Z3',
#   'INF789F013Z1',
#   'UTI Banking & PSU Debt Fund - Regular Plan - Quarterly IDCW',
#   '11.3998',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '126939',
#   'INF789F014Z9',
#   '-',
#   'UTI Banking & PSU Debt Fund- Regular Plan - Growth Option',
#   '16.3281',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119533',
#   'INF209K01S38',
#   '-',
#   'Aditya Birla Sun Life Corporate Bond Fund - Growth - Direct Plan',
#   '88.4633',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103178',
#   'INF209K01785',
#   '-',
#   'Aditya Birla Sun Life Corporate Bond Fund - Growth - Regular Plan',
#   '87.577',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '124832',
#   'INF209KA1KT0',
#   '-',
#   'Aditya Birla Sun Life Corporate Bond Fund -DIRECT - IDCW',
#   '12.5206',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '119532',
#   'INF209K01N90',
#   '-',
#   'Aditya Birla Sun Life Corporate Bond Fund -DIRECT - MONTHLY IDCW',
#   '12.4822',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '124833',
#   'INF209KA1KS2',
#   '-',
#   'Aditya Birla Sun Life Corporate Bond Fund -REGULAR - IDCW',
#   '12.6913',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103183',
#   'INF209K01983',
#   'INF209K01DL8',
#   'Aditya Birla Sun Life Corporate Bond Fund -REGULAR - MONTHLY IDCW',
#   '12.378',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103177',
#   '-',
#   '-',
#   'Aditya Birla Sun Life Income Fund-Plan A(Dividend)',
#   '11.7535',
#   '11-Feb-2011'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103179',
#   '-',
#   'INF209K01DI4',
#   'Aditya Birla Sun Life Income Fund-Plan D(54EA Dividend)',
#   '10.6457',
#   '11-Feb-2011'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103180',
#   '-',
#   '-',
#   'Aditya Birla Sun Life Income Fund-Plan E(54EA Growth)',
#   '35.2986',
#   '11-Feb-2011'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103181',
#   '-',
#   '-',
#   'Aditya Birla Sun Life Income Fund-PLan F(54EB Dividend)',
#   '15.5708',
#   '11-Feb-2011'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '103182',
#   '-',
#   '-',
#   'Aditya Birla Sun Life Income Fund-Plan G(54EB Growth)',
#   '35.0763',
#   '11-Feb-2011'],
#  ['Axis Mutual Fund',
#   '141586',
#   'INF846K01ZN6',
#   '-',
#   'Axis Corporate Debt Fund - Direct Plan - Daily IDCW',
#   '10.2348',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141590',
#   'INF846K01ZQ9',
#   'INF846K01ZR7',
#   'Axis Corporate Debt Fund - Direct Plan - Monthly IDCW',
#   '10.2259',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141591',
#   'INF846K01ZS5',
#   'INF846K01ZT3',
#   'Axis Corporate Debt Fund - Direct Plan - Regular IDCW',
#   '13.8098',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141587',
#   'INF846K01ZO4',
#   'INF846K01ZP1',
#   'Axis Corporate Debt Fund - Direct Plan - Weekly IDCW',
#   '10.3786',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141588',
#   'INF846K01ZM8',
#   '-',
#   'Axis Corporate Debt Fund - Direct Plan Growth',
#   '13.8140',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141589',
#   'INF846K01ZV9',
#   '-',
#   'Axis Corporate Debt Fund - Regular Plan - Daily IDCW',
#   '10.2347',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141594',
#   'INF846K01ZY3',
#   'INF846K01ZZ0',
#   'Axis Corporate Debt Fund - Regular Plan - Monthly IDCW',
#   '10.2192',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141595',
#   'INF846K01A03',
#   'INF846K01A11',
#   'Axis Corporate Debt Fund - Regular Plan - Regular IDCW',
#   '13.3901',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141592',
#   'INF846K01ZW7',
#   'INF846K01ZX5',
#   'Axis Corporate Debt Fund - Regular Plan - Weekly IDCW',
#   '10.2545',
#   '16-Jul-2021'],
#  ['Axis Mutual Fund',
#   '141593',
#   'INF846K01ZU1',
#   '-',
#   'Axis Corporate Debt Fund - Regular Plan Growth',
#   '13.3891',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '119983',
#   'INF251K01GU4',
#   'INF251K01GV2',
#   'BNP Paribas Corporate Bond Fund - Direct Plan - Annual Income Distribution cum Capital Withdrawal Option',
#   '11.1191',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '119984',
#   'INF251K01GP4',
#   '-',
#   'BNP Paribas Corporate Bond Fund - Direct Plan - Growth Option',
#   '23.0083',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '119985',
#   'INF251K01GQ2',
#   'INF251K01GR0',
#   'BNP Paribas Corporate Bond Fund - Direct Plan - Monthly Income Distribution cum Capital Withdrawal Option',
#   '10.4949',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '119986',
#   'INF251K01GS8',
#   'INF251K01GT6',
#   'BNP Paribas Corporate Bond Fund - Direct Plan - Quarterly Income Distribution cum Capital Withdrawal Option',
#   '10.7303',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '114100',
#   'INF251K01EN4',
#   'INF251K01EO2',
#   'BNP PARIBAS Corporate Bond Fund - Regular Plan - Annual-Income Distribution cum Capital Withdrawal Option',
#   '11.0021',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '114099',
#   'INF251K01EI4',
#   '-',
#   'BNP PARIBAS Corporate Bond Fund - Regular Plan - Growth Option',
#   '25.3820',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '114105',
#   'INF251K01EJ2',
#   'INF251K01EK0',
#   'BNP PARIBAS Corporate Bond Fund - Regular Plan - Monthly-Income Distribution cum Capital Withdrawal Option',
#   '10.3978',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '114097',
#   'INF251K01EL8',
#   'INF251K01EM6',
#   'BNP PARIBAS Corporate Bond Fund - Regular Plan - Quarterly-Income Distribution cum Capital Withdrawal Option',
#   '10.4579',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '117949',
#   'INF251K01EU9',
#   'INF251K01EV7',
#   'BNP PARIBAS CORPORATE BOND FUND ANNUAL Income Distribution cum Capital Withdrawal OPTION',
#   '10.9643',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '117951',
#   'INF251K01EP9',
#   '-',
#   'BNP PARIBAS CORPORATE BOND FUND GROWTH OPTION',
#   '21.9787',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '117950',
#   'INF251K01EQ7',
#   'INF251K01ER5',
#   'BNP PARIBAS CORPORATE BOND FUND MONTHLY Income Distribution cum Capital Withdrawal OPTION',
#   '10.3668',
#   '16-Jul-2021'],
#  ['BNP Paribas Mutual Fund',
#   '117948',
#   'INF251K01ES3',
#   'INF251K01ET1',
#   'BNP PARIBAS CORPORATE BOND FUND QUARTERLY Income Distribution cum Capital Withdrawal OPTION',
#   '10.4219',
#   '16-Jul-2021'],
#  ['Canara Robeco Mutual Fund',
#   '126685',
#   'INF760K01HB2',
#   '-',
#   'CANARA ROBECO CORPORATE BOND FUND - DIRECT PLAN - GROWTH OPTION',
#   '18.3926',
#   '16-Jul-2021'],
#  ['Canara Robeco Mutual Fund',
#   '126686',
#   'INF760K01HC0',
#   'INF760K01HD8',
#   'CANARA ROBECO CORPORATE BOND FUND - DIRECT PLAN - IDCW (Payout/Reinvestment)',
#   '12.1818',
#   '16-Jul-2021'],
#  ['Canara Robeco Mutual Fund',
#   '126687',
#   'INF760K01GY6',
#   '-',
#   'CANARA ROBECO CORPORATE BOND FUND - REGULAR PLAN - GROWTH OPTION',
#   '17.6072',
#   '16-Jul-2021'],
#  ['Canara Robeco Mutual Fund',
#   '126688',
#   'INF760K01GZ3',
#   'INF760K01HA4',
#   'CANARA ROBECO CORPORATE BOND FUND - REGULAR PLAN - IDCW (Payout/Reinvestment)',
#   '11.6761',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144646',
#   'INF740KA1KE8',
#   '-',
#   'DSP Corporate Bond Fund - Direct - Growth',
#   '12.9596',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144647',
#   'INF740KA1KF5',
#   'INF740KA1KG3',
#   'DSP Corporate Bond Fund - Direct - IDCW',
#   '11.2320',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144651',
#   'INF740KA1KH1',
#   'INF740KA1KI9',
#   'DSP Corporate Bond Fund - Direct - IDCW - Monthly',
#   '10.4492',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144648',
#   'INF740KA1KJ7',
#   'INF740KA1KK5',
#   'DSP Corporate Bond Fund - Direct - IDCW - Quarterly ',
#   '11.1098',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144644',
#   'INF740KA1JX0',
#   '-',
#   'DSP Corporate Bond Fund - Regular - Growth',
#   '12.8663',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144650',
#   'INF740KA1JY8',
#   'INF740KA1JZ5',
#   'DSP Corporate Bond Fund - Regular - IDCW',
#   '11.2053',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144645',
#   'INF740KA1KA6',
#   'INF740KA1KB4',
#   'DSP Corporate Bond Fund - Regular - IDCW - Monthly',
#   '10.4316',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '144649',
#   'INF740KA1KC2',
#   'INF740KA1KD0',
#   'DSP Corporate Bond Fund - Regular - IDCW - Quarterly ',
#   '10.4848',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '119289',
#   'INF090I01KC0',
#   '-',
#   'Franklin India Corporate Debt Fund - Direct - Bonus',
#   '0.0000',
#   '08-May-2015'],
#  ['Franklin Templeton Mutual Fund',
#   '118569',
#   'INF090I01FW8',
#   '-',
#   'Franklin India Corporate Debt Fund - Direct - GROWTH',
#   '83.0825',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '100528',
#   'INF090I01DG6',
#   '-',
#   'Franklin India Corporate Debt Fund - Growth',
#   '78.3915',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '100532',
#   'INF090I01DC5',
#   '-',
#   'Franklin India Corporate Debt Fund - Monthly Bonus',
#   '0.0000',
#   '08-Jun-2015'],
#  ['Franklin Templeton Mutual Fund',
#   '100527',
#   'INF090I01DH4',
#   'INF090I01DI2',
#   'Franklin India Corporate Debt Fund - Plan A - Annual - IDCW',
#   '17.5670',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118570',
#   'INF090I01FX6',
#   'INF090I01FY4',
#   'Franklin India Corporate Debt Fund - Plan A - Direct - Annual - IDCW',
#   '19.1750',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118573',
#   'INF090I01FU2',
#   'INF090I01FV0',
#   'Franklin India Corporate Debt Fund - Plan A - Direct - Half yearly - IDCW',
#   '15.5309',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118571',
#   'INF090I01FQ0',
#   'INF090I01FR8',
#   'Franklin India Corporate Debt Fund - Plan A - Direct - Monthly - IDCW',
#   '17.3625',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118572',
#   'INF090I01FS6',
#   'INF090I01FT4',
#   'Franklin India Corporate Debt Fund - Plan A - Direct - Quarterly - IDCW',
#   '14.3562',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '100531',
#   'INF090I01DN2',
#   'INF090I01DO0',
#   'Franklin India Corporate Debt Fund - Plan B - Half yearly - IDCW',
#   '13.9545',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '100529',
#   'INF090I01DJ0',
#   'INF090I01DK8',
#   'Franklin India Corporate Debt Fund - Plan B - Monthly - IDCW',
#   '15.9541',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '100530',
#   'INF090I01DL6',
#   'INF090I01DM4',
#   'Franklin India Corporate Debt Fund - Plan B - Quarterly - IDCW',
#   '13.1436',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '113070',
#   'INF179K01DC2',
#   '-',
#   'HDFC Corporate Bond Fund - Growth Option',
#   '25.3914',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118987',
#   'INF179K01XD8',
#   '-',
#   'HDFC Corporate Bond Fund - Growth Option - Direct Plan',
#   '25.6747',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '132848',
#   'INF179KA1D33',
#   '-',
#   'HDFC Corporate Bond Fund - IDCW Option',
#   '17.2699',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '132849',
#   'INF179KA1D17',
#   '-',
#   'HDFC Corporate Bond Fund - IDCW Option - Direct Plan',
#   '17.6215',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '113071',
#   'INF179K01DD0',
#   'INF179K01DE8',
#   'HDFC Corporate Bond Fund - Quarterly IDCW Option',
#   '10.4667',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118986',
#   'INF179K01XB2',
#   'INF179K01XC0',
#   'HDFC Corporate Bond Fund - Quarterly IDCW Option - Direct Plan',
#   '10.3899',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148492',
#   'INF336L01PH9',
#   '-',
#   'HSBC Corporate Bond Fund - Direct Plan - Growth',
#   '10.3875',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148496',
#   'INF336L01PO5',
#   '-',
#   'HSBC Corporate Bond Fund - Regular Plan - Growth',
#   '10.3532',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148494',
#   'INF336L01PI7',
#   'INF336L01PJ5',
#   'HSBC Corporate Bond Fund Direct Half Yearly IDCW',
#   '10.3875',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148493',
#   'INF336L01PL1',
#   'INF336L01PK3',
#   'HSBC Corporate Bond Fund Direct Monthly IDCW',
#   '10.2146',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148495',
#   'INF336L01PM9',
#   'INF336L01PN7',
#   'HSBC Corporate Bond Fund Direct Quarterly IDCW',
#   '10.2469',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148499',
#   'INF336L01PP2',
#   'INF336L01PQ0',
#   'HSBC Corporate Bond Fund Half Yearly IDCW',
#   '10.3532',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148497',
#   'INF336L01PS6',
#   'INF336L01PR8',
#   'HSBC Corporate Bond Fund Monthly IDCW',
#   '10.0644',
#   '16-Jul-2021'],
#  ['HSBC Mutual Fund',
#   '148498',
#   'INF336L01PT4',
#   'INF336L01PU2',
#   'HSBC Corporate Bond Fund Quarterly IDCW',
#   '10.2225',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '130947',
#   'INF109KA1I84',
#   '-',
#   'ICICI Prudential Corporate Bond Fund - Bonus',
#   '14.9782',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '111988',
#   'INF109K01CR9',
#   '-',
# ...
#   '16-Jul-2021'],
#  ['Union Mutual Fund',
#   '119311',
#   'INF582M01799',
#   '-',
#   'Union Dynamic Bond Fund - Direct Plan - Growth Option',
#   '19.8466',
#   '16-Jul-2021'],
#  ['Union Mutual Fund',
#   '119310',
#   'INF582M01815',
#   'INF582M01807',
#   'Union Dynamic Bond Fund - Direct Plan - IDCW Option',
#   '13.2940',
#   '16-Jul-2021'],
#  ['Union Mutual Fund',
#   '116555',
#   'INF582M01336',
#   '-',
#   'Union Dynamic Bond Fund - Growth Option',
#   '18.9755',
#   '16-Jul-2021'],
#  ['Union Mutual Fund',
#   '116556',
#   'INF582M01351',
#   'INF582M01344',
#   'Union Dynamic Bond Fund - IDCW Option',
#   '12.6507',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148118',
#   '-',
#   '-',
#   'UTI - Dynamic Bond Fund (Segregated - 17022020) - Direct Plan - Growth Option',
#   '0.3234',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148117',
#   '-',
#   '-',
#   'UTI - Dynamic Bond Fund (Segregated - 17022020) - Regular Plan - Growth Option',
#   '0.3084',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148125',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Direct Plan - Annual IDCW',
#   '0.1737',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148124',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Direct Plan - Flexi IDCW',
#   '0.1759',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148120',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Direct Plan - Half-Yearly IDCW',
#   '0.1742',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148121',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Direct Plan - Quarterly IDCW',
#   '0.2489',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148122',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Regular Plan - Annual IDCW',
#   '0.1695',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148123',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Regular Plan - Flexi IDCW',
#   '0.1707',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148119',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Regular Plan - Half-Yearly IDCW',
#   '0.1673',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '148126',
#   '-',
#   '-',
#   'UTI Dynamic Bond Fund ( Segregated - 17022020 ) - Regular Plan - Quarterly IDCW',
#   '0.1826',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '135536',
#   'INF789FA1S65',
#   'INF789FA1S73',
#   'UTI Dynamic Bond Fund - Direct Plan - Annual IDCW',
#   '11.5132',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '133180',
#   'INF789FA1S81',
#   'INF789FA1S99',
#   'UTI Dynamic Bond Fund - Direct Plan - Flexi IDCW',
#   '11.6772',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '120762',
#   'INF789F01XD4',
#   '-',
#   'UTI Dynamic Bond Fund - Direct Plan - Growth Option',
#   '22.366',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '134788',
#   'INF789FA1S40',
#   'INF789FA1S57',
#   'UTI Dynamic Bond Fund - Direct Plan - Half-Yearly IDCW',
#   '11.5577',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '120763',
#   'INF789F01XB8',
#   'INF789F01XC6',
#   'UTI Dynamic Bond Fund - Direct Plan - Quarterly IDCW',
#   '17.2113',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '133852',
#   'INF789FA1S08',
#   'INF789FA1S16',
#   'UTI Dynamic Bond Fund - Regular Plan - Annual IDCW',
#   '11.1517',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '135336',
#   'INF789FA1S24',
#   'INF789FA1S32',
#   'UTI Dynamic Bond Fund - Regular Plan - Flexi IDCW',
#   '11.2356',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '113077',
#   'INF789F01JQ5',
#   '-',
#   'UTI Dynamic Bond Fund - Regular Plan - Growth Option',
#   '21.1982',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '139181',
#   'INF789FA1R82',
#   'INF789FA1R90',
#   'UTI Dynamic Bond Fund - Regular Plan - Half-Yearly IDCW',
#   '10.9954',
#   '16-Jul-2021'],
#  ['UTI Mutual Fund',
#   '113078',
#   'INF789F01JO0',
#   'INF789F01JP7',
#   'UTI Dynamic Bond Fund - Regular Plan - Quarterly IDCW',
#   '11.9953',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122645',
#   'INF209K01UW9',
#   '-',
#   'Aditya Birla Sun Life Floating Rate Fund-Direct - daily IDCW',
#   '100.2905',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122648',
#   'INF209K01UY5',
#   '-',
#   'Aditya Birla Sun Life Floating Rate Fund-Direct - weekly IDCW',
#   '100.9874',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122646',
#   'INF209K01UX7',
#   '-',
#   'Aditya Birla Sun Life Floating Rate Fund-Direct Plan-Growth',
#   '275.5252',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122643',
#   '-',
#   'INF209KA1LN1',
#   'Aditya Birla Sun Life Floating Rate Fund-Regular - DAILY IDCW',
#   '100.5223',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122647',
#   '-',
#   'INF209K01MH7',
#   'Aditya Birla Sun Life Floating Rate Fund-REGULAR - WEEKLY IDCW',
#   '100.9526',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122644',
#   'INF209K01MG9',
#   '-',
#   'Aditya Birla Sun Life Floating Rate Fund-Regular Plan-Growth',
#   '270.4511',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122649',
#   '-',
#   'INF209K01MI5',
#   'Aditya Birla Sun Life Floating Rate Fund-RETAIL - WEEKLY IDCW',
#   '100.9526',
#   '16-Jul-2021'],
#  ['Aditya Birla Sun Life Mutual Fund',
#   '122650',
#   'INF209K01MF1',
#   '-',
#   'Aditya Birla Sun Life Floating Rate Fund-Retail Plan-Growth',
#   '391.166',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '148771',
#   'INF740KA1PV1',
#   '-',
#   'DSP Floater Fund - Direct Plan - Growth',
#   '10.2124',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '148769',
#   'INF740KA1PW9',
#   'INF740KA1PX7',
#   'DSP Floater Fund - Direct Plan - IDCW',
#   '10.2124',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '148768',
#   'INF740KA1PS7',
#   '-',
#   'DSP Floater Fund - Regular Plan - Growth',
#   '10.2024',
#   '16-Jul-2021'],
#  ['DSP Mutual Fund',
#   '148770',
#   'INF740KA1PT5',
#   'INF740KA1PU3',
#   'DSP Floater Fund - Regular Plan - IDCW',
#   '10.2024',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118508',
#   'INF090I01LK1',
#   '-',
#   'Franklin India Floating Rate Fund - Direct - Growth',
#   '33.7097',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '118507',
#   '-',
#   'INF090I01LL9',
#   'Franklin India Floating Rate Fund - Direct - IDCW ',
#   '10.0531',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '101048',
#   'INF090I01LM7',
#   '-',
#   'Franklin India Floating Rate Fund - Growth Plan',
#   '31.7611',
#   '16-Jul-2021'],
#  ['Franklin Templeton Mutual Fund',
#   '101044',
#   '-',
#   'INF090I01LN5',
#   'Franklin India Floating Rate Fund - IDCW ',
#   '10.1526',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '106838',
#   '-',
#   'INF179K01699',
#   'HDFC Floating Rate Debt Fund - Daily IDCW Option',
#   '10.0809',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118959',
#   '-',
#   '-',
#   'HDFC Floating Rate Debt Fund - Direct Plan - Daily IDCW',
#   '10.0809',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118961',
#   'INF179K01VQ4',
#   '-',
#   'HDFC Floating Rate Debt Fund - Direct Plan - Growth Option',
#   '39.0104',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118960',
#   'INF179K01VO9',
#   'INF179K01VP6',
#   'HDFC Floating Rate Debt Fund - Direct Plan - Monthly IDCW',
#   '10.1826',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '118962',
#   '-',
#   '-',
#   'HDFC Floating Rate Debt Fund - Direct Plan - Weekly IDCW',
#   '10.0601',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '106841',
#   'INF179K01707',
#   '-',
#   'HDFC Floating Rate Debt Fund - Growth Option',
#   '38.596',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '106839',
#   'INF179K01715',
#   'INF179K01723',
#   'HDFC Floating Rate Debt Fund - Monthly IDCW Option',
#   '10.1814',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '106840',
#   'INF179K01731',
#   'INF179K01749',
#   'HDFC Floating Rate Debt Fund - Weekly IDCW Option',
#   '10.0598',
#   '16-Jul-2021'],
#  ['HDFC Mutual Fund',
#   '101483',
#   '-',
#   'INF179K01640',
#   'HDFC Floating Rate Debt Fund - Retail Daily Div Option',
#   '10.0809',
#   '10-May-2019'],
#  ['HDFC Mutual Fund',
#   '101481',
#   'INF179K01632',
#   '-',
#   'HDFC Floating Rate Debt Fund - Retail Growth Option',
#   '31.6659',
#   '10-May-2019'],
#  ['HDFC Mutual Fund',
#   '101484',
#   'INF179K01657',
#   'INF179K01665',
#   'HDFC Floating Rate Debt Fund - Retail Monthly Div option',
#   '10.1682',
#   '10-May-2019'],
#  ['HDFC Mutual Fund',
#   '101482',
#   'INF179K01681',
#   'INF179K01673',
#   'HDFC Floating Rate Debt Fund - Retail Weekly Div Option',
#   '10.1483',
#   '10-May-2019'],
#  ['ICICI Prudential Mutual Fund',
#   '130899',
#   'INF109KA1I43',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Bonus',
#   '151.7062',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101804',
#   'INF109K01AW3',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Daily IDCW',
#   '101.3521',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120423',
#   '-',
#   'INF109K01P24',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Daily IDCW',
#   '101.3521',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120427',
#   'INF109K01P40',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Fortnightly IDCW',
#   '101.9685',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120425',
#   'INF109K01P57',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Growth',
#   '351.3548',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120426',
#   'INF109K01P65',
#   'INF109K01P32',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - IDCW Others',
#   '156.3799',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '122607',
#   'INF109K018Z6',
#   'INF109K017Z8',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Monthly IDCW',
#   '102.1116',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '125216',
#   'INF109KA1012',
#   'INF109K019Z4',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Quarterly IDCW',
#   '106.2924',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '120424',
#   'INF109K01P73',
#   'INF109K01P81',
#   'ICICI Prudential Floating Interest Fund - Direct Plan - Weekly IDCW',
#   '102.0458',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '101803',
#   'INF109K01AZ6',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Fortnightly IDCW',
#   '101.9659',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '101802',
#   'INF109K01AX1',
#   '-',
#   'ICICI Prudential Floating Interest Fund - Growth',
#   '330.3072',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '115510',
#   'INF109K01WQ9',
#   'INF109K01WP1',
#   'ICICI Prudential Floating Interest Fund - IDCW Others',
#   '152.0016',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '122606',
#   'INF109KA1038',
#   'INF109KA1020',
#   'ICICI Prudential Floating Interest Fund - Monthly IDCW',
#   '102.7799',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '122891',
#   'INF109KA1053',
#   'INF109KA1046',
#   'ICICI Prudential Floating Interest Fund - Quarterly IDCW',
#   '105.0582',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '111545',
#   'INF109K01EN4',
#   'INF109K01AY9',
#   'ICICI Prudential Floating Interest Fund - Weekly IDCW',
#   '102.0376',
#   '16-Jul-2021'],
#  ['ICICI Prudential Mutual Fund',
#   '101800',
#   'INF109K01928',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan A - Dividend Daily',
#   '100.0251',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101796',
#   'INF109K01910',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan A - Fortnightly Dividend',
#   '101.3988',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101795',
#   'INF109K01936',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan A - Growth',
#   '300.7518',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '111544',
#   'INF109K01EK0',
#   'INF109K01944',
#   'ICICI Prudential Floating Interest Fund Plan A - Weekly Dividend Option',
#   '101.1821',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101799',
#   'INF109K01951',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan B - Dividend Daily',
#   '100.025',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101794',
#   'INF109K01969',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan B - Fortnightly Dividend',
#   '101.397',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101793',
#   'INF109K01977',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan B - Growth',
#   '324.7401',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '111543',
#   'INF109K01EL8',
#   'INF109K01985',
#   'ICICI Prudential Floating Interest Fund Plan B - Weekly Dividend Option',
#   '101.1822',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101801',
#   'INF109K01AA9',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan C - Dividend Daily',
#   '100.9403',
#   '27-Feb-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101798',
#   'INF109K01993',
#   '-',
#   'ICICI Prudential Floating Interest Fund Plan C - Fortnightly Dividend',
#   '101.3966',
#   '24-Apr-2020'],
#  ['ICICI Prudential Mutual Fund',
#   '101797',
#   'INF109K01AB7',
#   '-',
#   'ICICI Prudential Savings Fund Plan C - Growth',
#   '218.1632',
#   '15-Jun-2015'],
#  ['ICICI Prudential Mutual Fund',
#   '111546',
#   'INF109K01EM6',
#   'INF109K01AC5',
#   'ICICI Prudential Savings Fund Plan C - Weekly Dividend Option',
#   '101.3043',
#   '15-Feb-2017'],
#  ['IDFC Mutual Fund',
#   '148717',
#   'INF194KB1BJ6',
#   'INF194KB1BK4',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN ANNUAL IDCW',
#   '10.1797',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148714',
#   '-',
#   'INF194KB1BB3',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN DAILY IDCW',
#   '10.0258',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148711',
#   'INF194KB1BA5',
#   '-',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN GROWTH',
#   '10.1849',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148713',
#   'INF194KB1BD9',
#   'INF194KB1BE7',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN MONTHLY IDCW',
#   '10.0720',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148712',
#   'INF194KB1BF4',
#   'INF194KB1BG2',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN QUARTERLY IDCW',
#   '10.0603',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148716',
#   '-',
#   'INF194KB1BC1',
#   'IDFC FLOATING RATE FUND  - DIRECT PLAN WEEKLY IDCW',
#   '10.0394',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148718',
#   'INF194KB1AY7',
#   'INF194KB1AZ4',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN ANNUAL IDCW',
#   '10.1644',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148710',
#   '-',
#   'INF194KB1AQ3',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN DAILY IDCW',
#   '10.0258',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148705',
#   'INF194KB1AP5',
#   '-',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN GROWTH',
#   '10.1650',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148707',
#   'INF194KB1AS9',
#   'INF194KB1AT7',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN MONTHLY IDCW',
#   '10.0513',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148709',
#   'INF194KB1AW1',
#   'INF194KB1AX9',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN PERIODIC IDCW',
#   '10.1646',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148706',
#   'INF194KB1AU5',
#   'INF194KB1AV3',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN QUARTERLY IDCW',
#   '10.0557',
#   '16-Jul-2021'],
#  ['IDFC Mutual Fund',
#   '148708',
#   '-',
#   'INF194KB1AR1',
#   'IDFC FLOATING RATE FUND  - REGULAR PLAN WEEKLY IDCW',
#   '10.0384',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '147269',
#   'INF174KA1EC0',
#   '-',
#   'KOTAK FLOATING RATE FUND-DIRECT PLAN-GROWTH OPTION',
#   '1186.6446',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '147267',
#   '-',
#   'INF174KA1EF3',
#   'KOTAK FLOATING RATE FUND-DIRECT PLAN-MONTHLY Reinvestment of Income Distributioncum capital withdrawal option',
#   '1053.5653',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '147266',
#   'INF174KA1DY6',
#   '-',
#   'KOTAK FLOATING RATE FUND-REGULAR PLAN-GROWTH OPTION',
#   '1177.8701',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '147265',
#   '-',
#   'INF174KA1EB2',
#   'KOTAK FLOATING RATE FUND-REGULAR PLAN-MONTHLY Reinvestment of Income Distribution cum capital withdrawal option',
#   '1067.6556',
#   '16-Jul-2021'],
#  ['Kotak Mahindra Mutual Fund',
#   '147271',
#   '-',
#   'INF174KA1DZ3',
#   'KOTAK FLOATING RATE FUND-REGULAR PLAN-weekly Reinvestment of Income Distribution cum capital withdrawal option',
#   '1094.41',
#   '16-Jul-2021'],
#  ['Nippon India Mutual Fund',
#   '118656',
#   'INF204K01E05',
#   '-',
#   'Nippon India Floating Rate Fund  - Direct Plan Growth Plan - Growth Option',
#   '36.7153',
#   '16-Jul-2021'],
#  ...]

# %%
df = pd.DataFrame(df_list)

# %%
df.head()
# Out:
#                                    0            1  \
# 0                       Company Name  Scheme Code
# 1  Aditya Birla Sun Life Mutual Fund       119551
# 2  Aditya Birla Sun Life Mutual Fund       119552
# 3  Aditya Birla Sun Life Mutual Fund       119553
# 4  Aditya Birla Sun Life Mutual Fund       108272
#
#                               2                      3  \
# 0  ISIN Div Payout/ ISIN Growth  ISIN Div Reinvestment
# 1                  INF209KA12Z1           INF209KA13Z9
# 2                  INF209K01YM2                      -
# 3                  INF209K01YO8                      -
# 4                  INF209K01LX6           INF209KA11Z3
#
#                                                    4                5  \
# 0                                        Scheme Name  Net Asset Value
# 1  Aditya Birla Sun Life Banking & PSU Debt Fund ...         142.5092
# 2  Aditya Birla Sun Life Banking & PSU Debt Fund ...         114.9651
# 3  Aditya Birla Sun Life Banking & PSU Debt Fund ...         112.3226
# 4  Aditya Birla Sun Life Banking & PSU Debt Fund ...         162.3519
#
#              6
# 0         Date
# 1  16-Jul-2021
# 2  16-Jul-2021
# 3  16-Jul-2021
# 4  16-Jul-2021

# %%
# store dataframe into csv file
df.to_csv('NAVAII.csv', index=None)
